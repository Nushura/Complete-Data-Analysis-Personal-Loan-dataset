# %% [markdown]
# # Information System Solutions and Design (2250)
#
# # Assignment 3: Data Science Project
#
# ## Nushura Islam (s3796107)

# %% [markdown]
# ## Phase 2: Data Understanding

# %% [markdown]
# # Importing libraries

# %%
# Importing numpy as it assists in doing rapid mathematical operations 
import numpy as np

# Importing pandas which is built on top of numpy
import pandas as pd

# Importing SimpleImputer to assign missing values 
from sklearn.impute import SimpleImputer

# For graph plotting purposes importing matplotlib
import matplotlib.pyplot as plt 
# This will further help to plot graphs within the notebook
# %matplotlib inline 

# Importing seaborn which is built on top of matplotlib
import seaborn as sns

# %% [markdown]
# # Loading and checking data

# %%
# Checking and storing missing values in the variable called 'missing_values'
missing_values = ['?', '--', ' ', 'NA', 'N/A', '-']

# Loading the personal loan dataframe from computer and 
# Also checking and converting the missing values characteres to NA format
# If the delimiter is not in the standard comma separated format the it will be 
personal_loan_df = pd.read_csv("personal-loan.csv", na_values=missing_values)
personal_loan_df
# Out:
#       customer_id   age  yrs_experience  family_size  \
# 0            3815  40.0             9.0          3.0
# 1            5737  65.0            27.0          4.0
# 2            4209  61.0             3.0          2.0
# 3            4734  29.0            14.0          1.0
# 4            2551  43.0            23.0          4.0
# ...           ...   ...             ...          ...
# 5995         5440  36.0             4.0          1.0
# 5996         1251  56.0            25.0          2.0
# 5997         2454  34.0            11.0          2.0
# 5998         1435  30.0             NaN          2.0
# 5999         1409  47.0            22.0          3.0
#
#                education_level  income  mortgage_amt credit_card_acct  \
# 0                     Graduate    60.0             0              yes
# 1     Advanced or Professional    36.0            90               no
# 2                Undergraduate   145.0           314               no
# ...

# %%
# Checking the type of object
type(personal_loan_df)

# The output confirms that the data set has been successfully 
# loaded into a dataframe object
# Out:
# pandas.core.frame.DataFrame

# %%
# For checking if there are any null values within the dataframe and 
# to get an overall idea about the datatypes of each column
personal_loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         6000 non-null   int64
#  1   age                 5620 non-null   float64
#  2   yrs_experience      5636 non-null   float64
#  3   family_size         5615 non-null   float64
#  4   education_level     6000 non-null   object
#  5   income              5623 non-null   float64
#  6   mortgage_amt        6000 non-null   int64
#  7   credit_card_acct    6000 non-null   object
#  8   credit_card_spend   6000 non-null   float64
#  9   share_trading_acct  6000 non-null   int64
#  10  fixed_deposit_acct  6000 non-null   int64
#  11  online_acct         6000 non-null   object
#  12  personal_loan       6000 non-null   object
# dtypes: float64(5), int64(4), object(4)
# memory usage: 609.5+ KB

# %% [markdown]
# # Data Overview

# %% [markdown]
# ### Finding the number of rows and columns the data set has

# %%
# Using the hsape attribute to do the calculation
print(personal_loan_df.shape)
print(personal_loan_df.shape[0]) # Rows
print(personal_loan_df.shape[1]) # Columns

# It can be concluded that there are 6000 rows and 13 columns present in the dataset
# Out:
# (6000, 13)
# 6000
# 13

# %% [markdown]
# ### Displaying first 20 rows

# %%
# Displaying the first 20 rows of the data set
personal_loan_df.head(20)

# It can be observed by looking at the dataframe printed below that there are not a number (NaN) values present within the set.
# Out:
#     customer_id   age  yrs_experience  family_size           education_level  \
# 0          3815  40.0             9.0          3.0                  Graduate
# 1          5737  65.0            27.0          4.0  Advanced or Professional
# 2          4209  61.0             3.0          2.0             Undergraduate
# 3          4734  29.0            14.0          1.0             Undergraduate
# 4          2551  43.0            23.0          4.0                  Graduate
# 5          4491  44.0            18.0          3.0  Advanced or Professional
# 6           706  42.0            16.0          4.0  Advanced or Professional
# 7          5327  64.0            38.0          2.0             Undergraduate
# 8          5269  43.0             7.0          4.0                  Graduate
# 9          1918  25.0             8.0          1.0             Undergraduate
# 10         4542   NaN             NaN          NaN             Undergraduate
# ...

# %% [markdown]
# ### Checking if there are any null values in data

# %%
# Null values are denoted as NaN or blank spaces
# Whereas 0 is a valud value
print (f"Missing values : {personal_loan_df.isnull().sum().values.sum()}")

# It can be concluded from the result that there are 1506 null values
# Out:
# Missing values : 1506

# %% [markdown]
# ### Checking the unique values per column within the dataset

# %%
print (f"Unique values : \n\n{personal_loan_df.nunique()}")
# Out:
# Unique values :
#
# customer_id           3786
# age                     49
# yrs_experience          47
# family_size              6
# education_level          3
# income                 257
# mortgage_amt           300
# credit_card_acct         2
# credit_card_spend       85
# share_trading_acct       2
# fixed_deposit_acct       2
# online_acct              2
# personal_loan            2
# dtype: int64

# %% [markdown]
# The result of the previous cell concludes that there are 6 continuous variables
# - customer_id
# - age
# - yrs_experience
# - income
# - mortgage_amt
# - credit_card_spend
#
# This is determined because a column with more than 6 unique values are considered to be a continuous variable.
#
# All the other columns can be considered as categorical variable.

# %%
personal_loan_df.describe().T
# Out:
#                      count         mean          std   min      25%     50%  \
# customer_id         6000.0  3027.886667  1723.488432   3.0  1553.75  3045.5
# age                 5620.0    45.556940    13.373778  23.0    34.00    45.0
# yrs_experience      5636.0    21.182221    13.247945   0.0    10.00    21.0
# family_size         5615.0     2.468566     1.215636   1.0     1.00     2.0
# income              5623.0    88.143873    48.736053   8.0    52.00    82.0
# mortgage_amt        6000.0    67.585667    88.155099   0.0     0.00     0.0
# credit_card_spend   6000.0     0.627467     1.423450   0.0     0.00     0.0
# share_trading_acct  6000.0     0.099167     0.298911   0.0     0.00     0.0
# fixed_deposit_acct  6000.0     0.078167     0.268456   0.0     0.00     0.0
#
#                        75%     max
# customer_id         4511.0  6000.0
# age                   56.0    92.0
# yrs_experience        32.0    65.0
# family_size            4.0     7.0
# ...

# %% [markdown]
# The table presented on the earlier cell shows for each column:
#
# 1. The count of the number of variables
# 2. Mean value
# 3. Standard deviation
# 4. The minimum value
# 5. The maximum value
# 6. The 25th, 50th and 70th percentiles

# %% [markdown]
# # Correlations -- Using Seaborn

# %% [markdown]
# The greater the strength of the correlation between attributes, the more close is its correlation value to 1 or the darker is its color. And hence, the closer the correlation value to 0 or the lighter the color is means that the strength strength between relationships are weaker.
#
# That is represented by the code and result below. Correlation is computed using seaborn's heatmap function.

# %%
# Using seaborn library to plot the correlations as a heatmap
# 20, 20 is the width and hight of the heat map
plt.rcParams['figure.figsize'] = (20, 20)
sns.heatmap(personal_loan_df.corr(), annot = True, linewidths=.5, cmap="YlGnBu")

# Title of the heat map
plt.title('Correlation between features of\nPersonal Loan Dataset')

# Saving the graph to disk

# automatically adjusts subplot to fit in the figure area
plt.tight_layout()

# dpi=300 is print quality
plt.savefig('correlation-heatmap-rectangular.png', dpi=300)

# %% [markdown]
# It can be observed that the heatmap removed a few attributes that contained strings. The personal_loan outcome column is hence removed as well from the heatmap.
#
# However, by observing the heatmap, it can be concluded that the following attributes have the strongest correlation with each other, which also contributes to determining if an individual will take the loan. The attributes and their correlation values are:
#
# 1. Income and mortgage_amt: 0.13
# 2. Income and credit_card_spend: 0.15
# 3. Income and fixed_deposit_acct: 0.19
# 4. mortgage_amt and fixed_deposit_acct: 0.1
#
# Hence, income, mortgage_amt, credit_card_spend, and fixed_deposit_acct play a vital role in determining the probability of a particular individual taking a personal loan. For example, if an individual earns above a certain amount, they are most likely to take a loan as clients consider their chances of paying back before taking loans.
#
# Credit card spending will also increase the chances of someone taking a loan. This is because if their monthly expenditure is above a specific limit, then they will not lean towards taking any loans. People with fixed deposit accounts are likely to save money and hence can take a loan.

# %% [markdown]
# # Visualization

# %% [markdown]
# ### The percentage of people who took the loan VS who did not

# %%
# Plot a pie chart
labels = ["Not loaned", "Loaned"]
print(f"labels: {labels}")

# Getting the values from the "personal_loan" column and using values to get the values
values = personal_loan_df["personal_loan"].value_counts().values.tolist()
print(f"values: {values}")

# Using matplotlib to draw a simple pie chart
plt.figure(figsize=(5,5)) 
plt.pie(values, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title("Proportion of clients who \nloaned in dataset", fontsize=20) 


#plt.show() # if want to save to file - the file will be empty

# Save the graph to disk
plt.tight_layout() # automatically adjusts subplot to fit in the figure area
plt.savefig('pie_chart.png', dpi=300)
# Out:
# labels: ['Not loaned', 'Loaned']
# values: [5100, 900]

# %% [markdown]
# ### Splitting the data into loaned and not loaned

# %%
# Not loaned
not_loaned_df = personal_loan_df[personal_loan_df["personal_loan"]=='no']
not_loaned_df.head(10)
# Out:
#     customer_id   age  yrs_experience  family_size           education_level  \
# 0          3815  40.0             9.0          3.0                  Graduate
# 1          5737  65.0            27.0          4.0  Advanced or Professional
# 3          4734  29.0            14.0          1.0             Undergraduate
# 4          2551  43.0            23.0          4.0                  Graduate
# 5          4491  44.0            18.0          3.0  Advanced or Professional
# 6           706  42.0            16.0          4.0  Advanced or Professional
# 7          5327  64.0            38.0          2.0             Undergraduate
# 8          5269  43.0             7.0          4.0                  Graduate
# 9          1918  25.0             8.0          1.0             Undergraduate
# 10         4542   NaN             NaN          NaN             Undergraduate
#
#     income  mortgage_amt credit_card_acct  credit_card_spend  \
# ...

# %%
# loaned
loaned_df = personal_loan_df[personal_loan_df["personal_loan"]=='yes']
loaned_df.head(10)
# Out:
#     customer_id   age  yrs_experience  family_size           education_level  \
# 2          4209  61.0             3.0          2.0             Undergraduate
# 12         2179  64.0            13.0          2.0                  Graduate
# 20         3181  31.0            11.0          2.0                  Graduate
# 21         2330  29.0            31.0          2.0                  Graduate
# 25         1591  45.0            19.0          1.0                  Graduate
# 30         2381  35.0             5.0          2.0                  Graduate
# 32         3683  32.0            27.0          4.0  Advanced or Professional
# 36         4792  61.0            33.0          1.0  Advanced or Professional
# 39         5794  33.0            39.0          4.0  Advanced or Professional
# 44         5459  40.0            13.0          4.0             Undergraduate
#
#     income  mortgage_amt credit_card_acct  credit_card_spend  \
# ...

# %% [markdown]
# From the split the attributes which affects loans became clearer.

# %% [markdown]
# ### Impact of customer_id on loans

# %%
# Setting the size 
plt.figure(figsize=(15, 10))

# Plotting histogram
sns.histplot(data=not_loaned_df, x="customer_id", color="skyblue", label="Not loaned", kde=True)
sns.histplot(data=loaned_df, x="customer_id", color="green", label="Loaned", kde=True)

# Labels
plt.legend()
plt.title('Impact of customer_id on loans\n', fontsize = 25)
plt.xlabel("Customer ID")
plt.ylabel("Density")
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# It can be observed that both the loaned and not loaned clients has a uniform distribution.
# However, the percentage of not loaned clients are higher than the loaned clients.
# It proves that a lower percentage of people took a personal loan on the last campaign.

# %% [markdown]
# ## Exploring Attributes with Strongest Correlation

# %% [markdown]
# ### Impact of Income (Continuous variable) on loans

# %%
# Setting the size 
plt.figure(figsize=(15, 10))

# Plotting histogram
sns.histplot(data=not_loaned_df, x="income", color="skyblue", label="Not loaned", kde=True)
sns.histplot(data=loaned_df, x="income", color="green", label="Loaned", kde=True)

# Labels
plt.legend()
plt.title('Impact of Income on loans\n', fontsize = 25)
plt.xlabel("Income")
plt.ylabel("Density")

# Save the graph to disk
# plt.tight_layout() # automatically adjusts subplot to fit in the figure area
plt.savefig('Impact of Income on loans.png', dpi=300)

# %% [markdown]
# ### Impact of mortgage ammout (Continuous variable) on loans

# %%
# Setting the size 
plt.figure(figsize=(15, 10))

# Plotting histogram
sns.histplot(data=not_loaned_df, x="mortgage_amt", color="skyblue", label="Not loaned", kde=True)
sns.histplot(data=loaned_df, x="mortgage_amt", color="green", label="Loaned", kde=True)

# Labels
plt.legend()
plt.title('Impact of Mortgage Amount on loans\n', fontsize = 25)
plt.xlabel("Mortgage Amount")
plt.ylabel("Density")

# Save the graph to disk
# plt.tight_layout() # automatically adjusts subplot to fit in the figure area
plt.savefig('Impact of mortgage on loans.png', dpi=300)

# %% [markdown]
# ### Impact of credit card spend (Discrete variable) on loans

# %%
# Categorising the fixed_deposit_acct column to have yes and no categories instead of 1 and 0
def credit_card_spend_category(df): 
    if (df["credit_card_spend"] == 1) & (df["credit_card_spend"] <= 1.5):
        return "normal_sepnd"
    elif df["credit_card_spend"] > 1.5:
        return "high_spend"

    
# Use apply() to apply a lambda function for all the rows of the dataframe
# The lambda function calls the previously defined function fixed_deposit_acct_category()
# To which it passes the personal_loan_df as parameter
# And a category is returned and saved in a new column named "fixed_deposit_acct_category"
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html
# the backslash is a line continuation character - there should be nothing after it, not even a space
personal_loan_df["credit_card_spend_category"] = \
    personal_loan_df.apply(lambda personal_loan_df:credit_card_spend_category(personal_loan_df), axis = 1) # axis=1 = row-wise
# Checking if implementation is proper
personal_loan_df.head()
# Out:
#    customer_id   age  yrs_experience  family_size           education_level  \
# 0         3815  40.0             9.0          3.0                  Graduate
# 1         5737  65.0            27.0          4.0  Advanced or Professional
# 2         4209  61.0             3.0          2.0             Undergraduate
# 3         4734  29.0            14.0          1.0             Undergraduate
# 4         2551  43.0            23.0          4.0                  Graduate
#
#    income  mortgage_amt credit_card_acct  credit_card_spend  \
# 0    60.0             0              yes                1.7
# 1    36.0            90               no                0.0
# 2   145.0           314               no                0.0
# 3    52.0             0               no                0.0
# 4    33.0             0               no                0.0
#
#    share_trading_acct  fixed_deposit_acct online_acct personal_loan  \
# 0                   0                   0         yes            no
# ...

# %%
# Using seaborn to plot charts

# Plotting two separate plots side by side
# As a single plot
sns.countplot(x='credit_card_spend_category', 
              data=personal_loan_df)

plt.title('Credit Card Spend - Loaned vs Not Loaned', fontsize=30)
plt.xlabel("Credit Card Spend", fontsize=30)
plt.ylabel("Count", fontsize=30)
plt.tick_params(axis='both', which='both', labelsize=20) # x/y axes, minor/major ticks for plt

# Save the graph to disk
# plt.tight_layout() # automatically adjusts subplot to fit in the figure area
plt.savefig('Credit Card Spend.png', dpi=300)

# %% [markdown]
# ### Impact of fixed deposit account (Categorical variable) on loans

# %%
# Categorising the fixed_deposit_acct column to have yes and no categories instead of 1 and 0
def fixed_deposit_acct_category(df): 
    if df["fixed_deposit_acct"] == 1:
        return "Fixed Deposit Account"
    elif df["fixed_deposit_acct"] == 0:
        return "No Fixed Deposit Account"

    
# Use apply() to apply a lambda function for all the rows of the dataframe
# The lambda function calls the previously defined function fixed_deposit_acct_category()
# To which it passes the personal_loan_df as parameter
# And a category is returned and saved in a new column named "fixed_deposit_acct_category"
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html
# the backslash is a line continuation character - there should be nothing after it, not even a space
personal_loan_df["fixed_deposit_acct_category"] = \
    personal_loan_df.apply(lambda personal_loan_df:fixed_deposit_acct_category(personal_loan_df), axis = 1) # axis=1 = row-wise
# Checking if implementation is proper
personal_loan_df.head()
# Out:
#    customer_id   age  yrs_experience  family_size           education_level  \
# 0         3815  40.0             9.0          3.0                  Graduate
# 1         5737  65.0            27.0          4.0  Advanced or Professional
# 2         4209  61.0             3.0          2.0             Undergraduate
# 3         4734  29.0            14.0          1.0             Undergraduate
# 4         2551  43.0            23.0          4.0                  Graduate
#
#    income  mortgage_amt credit_card_acct  credit_card_spend  \
# 0    60.0             0              yes                1.7
# 1    36.0            90               no                0.0
# 2   145.0           314               no                0.0
# 3    52.0             0               no                0.0
# 4    33.0             0               no                0.0
#
#    share_trading_acct  fixed_deposit_acct online_acct personal_loan  \
# 0                   0                   0         yes            no
# ...

# %%
# Using seaborn to plot charts

# Plotting two separate plots side by side
# As a single plot
sns.countplot(x='fixed_deposit_acct_category', 
              data=personal_loan_df, # Whole dataset 
              hue='fixed_deposit_acct') # grouped by outcome

plt.title('Fixed Deposit Account - Loaned vs Not Loaned', fontsize=30)
plt.xlabel("Fixed Deposit Account", fontsize=30)
plt.ylabel("Count", fontsize=30)
plt.tick_params(axis='both', which='both', labelsize=20) # x/y axes, minor/major ticks for plt


# If you want to save the graph to disk
plt.tight_layout() # automatically1m adjusts subplot to fit in the figure area
plt.savefig('fixed_deposit_acct_category-side-by-side.png', dpi=300) # dpi=300 is print quality

# %% [markdown]
# ## Exploring relationship between every possible pairs of features

# %%
# Age VS customer_id
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="customer_id", y="age",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nAge versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("age")

sns.relplot(
    data=loaned_df, x="customer_id", y="age",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nAge versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("age")
# Out:
# Text(10.049999999999997, 0.5, 'age')

# %%
# yrs_experience VS customer_id
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="customer_id", y="yrs_experience",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nYears experience versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("yrs_experience")

sns.relplot(
    data=loaned_df, x="customer_id", y="yrs_experience",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nYears experience versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("yrs_experience")
# Out:
# Text(10.049999999999997, 0.5, 'yrs_experience')

# %%
# family_size VS customer_id
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="customer_id", y="family_size",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nfamily size versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("family_size")

sns.relplot(
    data=loaned_df, x="customer_id", y="family_size",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nfamily size versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("family_size")
# Out:
# Text(6.799999999999997, 0.5, 'family_size')

# %%
# education_level VS customer_id
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="customer_id", y="education_level",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\neducation_level versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("education_level")

sns.relplot(
    data=loaned_df, x="customer_id", y="education_level",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\neducation_level versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("education_level")
# Out:
# Text(-103.325, 0.5, 'education_level')

# %%
# income VS customer_id
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="customer_id", y="income",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nincome versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("income")

sns.relplot(
    data=loaned_df, x="customer_id", y="income",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nincome versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("income")
# Out:
# Text(3.674999999999997, 0.5, 'income')

# %%
# mortgage_amt VS customer_id
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="customer_id", y="mortgage_amt",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nmortgage_amt versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("mortgage_amt")

sns.relplot(
    data=loaned_df, x="customer_id", y="mortgage_amt",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nmortgage_amt versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("mortgage_amt")
# Out:
# Text(3.674999999999997, 0.5, 'mortgage_amt')

# %%
# credit_card_spend VS customer_id
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="customer_id", y="credit_card_spend",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\ncredit_card_spend versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("credit_card_spend")

sns.relplot(
    data=loaned_df, x="customer_id", y="credit_card_spend",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\ncredit_card_spend versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("credit_card_spend")
# Out:
# Text(16.424999999999997, 0.5, 'credit_card_spend')

# %%
# credit_card_spend VS customer_id
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="customer_id", y="personal_loan",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\ncredit_card_spend versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("credit_card_spend")

sns.relplot(
    data=loaned_df, x="customer_id", y="personal_loan",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\ncredit_card_spend versus Customer id\n', fontsize = 12)
plt.xlabel("customer_id")
plt.ylabel("credit_card_spend")
# Out:
# Text(5.549999999999997, 0.5, 'credit_card_spend')

# %%
# yrs_experience VS age
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="age", y="yrs_experience",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nyrs_experience versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("yrs_experience")

sns.relplot(
    data=loaned_df, x="age", y="yrs_experience",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nyrs_experience versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("yrs_experience")
# Out:
# Text(10.049999999999997, 0.5, 'yrs_experience')

# %%
# family_size VS age
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="age", y="family_size",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nfamily_size versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("family_size")

sns.relplot(
    data=loaned_df, x="age", y="family_size",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nfamily_size versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("family_size")
# Out:
# Text(6.799999999999997, 0.5, 'family_size')

# %%
# education_level VS age
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="age", y="education_level",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\neducation_level versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("education_level")

sns.relplot(
    data=loaned_df, x="age", y="education_level",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\neducation_level versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("education_level")
# Out:
# Text(-103.325, 0.5, 'education_level')

# %%
# income VS age
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="age", y="income",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nincome versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("income")

sns.relplot(
    data=loaned_df, x="age", y="income",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nincome versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("income")
# Out:
# Text(3.674999999999997, 0.5, 'income')

# %%
# mortgage_amt VS age
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="age", y="mortgage_amt",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nmortgage_amt versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("mortgage_amt")

sns.relplot(
    data=loaned_df, x="age", y="mortgage_amt",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nmortgage_amt versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("mortgage_amt")
# Out:
# Text(3.674999999999997, 0.5, 'mortgage_amt')

# %%
# credit_card_acct VS age
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="age", y="credit_card_acct",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\ncredit_card_acct versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("credit_card_acct")

sns.relplot(
    data=loaned_df, x="age", y="credit_card_acct",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\ncredit_card_acct versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("credit_card_acct")
# Out:
# Text(5.549999999999997, 0.5, 'credit_card_acct')

# %%
# fixed_deposit_acct VS age
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="age", y="personal_loan",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\ncredit_card_acct versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("credit_card_acct")

sns.relplot(
    data=loaned_df, x="age", y="personal_loan",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\ncredit_card_acct versus age\n', fontsize = 12)
plt.xlabel("age")
plt.ylabel("credit_card_acct")
# Out:
# Text(5.549999999999997, 0.5, 'credit_card_acct')

# %%
# family_size VS yrs_experience
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="yrs_experience", y="family_size",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nfamily_size versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("family_size")

sns.relplot(
    data=loaned_df, x="yrs_experience", y="family_size",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nfamily_size versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("family_size")
# Out:
# Text(6.799999999999997, 0.5, 'family_size')

# %%
# education_level VS yrs_experience
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="yrs_experience", y="education_level",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\neducation_level versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("education_level")

sns.relplot(
    data=loaned_df, x="yrs_experience", y="education_level",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\neducation_level versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("education_level")
# Out:
# Text(-103.325, 0.5, 'education_level')

# %%
# income VS yrs_experience
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="yrs_experience", y="income",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nincome versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("income")

sns.relplot(
    data=loaned_df, x="yrs_experience", y="income",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nincome versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("income")
# Out:
# Text(3.674999999999997, 0.5, 'income')

# %%
# mortgage_amt VS yrs_experience
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="yrs_experience", y="mortgage_amt",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nmortgage_amt versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("mortgage_amt")

sns.relplot(
    data=loaned_df, x="yrs_experience", y="mortgage_amt",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nmortgage_amt versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("mortgage_amt")
# Out:
# Text(3.674999999999997, 0.5, 'mortgage_amt')

# %%
# credit_card_acct VS yrs_experience
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="yrs_experience", y="credit_card_acct",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\ncredit_card_acct versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("credit_card_acct")

sns.relplot(
    data=loaned_df, x="yrs_experience", y="credit_card_acct",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\ncredit_card_acct versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("credit_card_acct")
# Out:
# Text(5.549999999999997, 0.5, 'credit_card_acct')

# %%
# credit_card_spend VS yrs_experience
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="yrs_experience", y="credit_card_spend",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\ncredit_card_spend versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("credit_card_spend")

sns.relplot(
    data=loaned_df, x="yrs_experience", y="credit_card_spend",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\ncredit_card_spend versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("credit_card_spend")
# Out:
# Text(16.424999999999997, 0.5, 'credit_card_spend')

# %%
# online_acct VS yrs_experience
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="yrs_experience", y="online_acct",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nonline_acct versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("online_acct")

sns.relplot(
    data=loaned_df, x="yrs_experience", y="online_acct",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nonline_acct versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("online_acct")
# Out:
# Text(5.549999999999997, 0.5, 'online_acct')

# %%
# personal_loan VS yrs_experience
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="yrs_experience", y="personal_loan",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\npersonal_loan versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("personal_loan")

sns.relplot(
    data=loaned_df, x="yrs_experience", y="personal_loan",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\npersonal_loan versus yrs_experience\n', fontsize = 12)
plt.xlabel("yrs_experience")
plt.ylabel("personal_loan")
# Out:
# Text(5.549999999999997, 0.5, 'personal_loan')

# %%
# education_level VS family_size
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="family_size", y="education_level",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\neducation_level versus family_size\n', fontsize = 12)
plt.xlabel("family_size")
plt.ylabel("education_level")

sns.relplot(
    data=loaned_df, x="family_size", y="education_level",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\neducation_level versus family_size\n', fontsize = 12)
plt.xlabel("family_size")
plt.ylabel("education_level")
# Out:
# Text(-103.325, 0.5, 'education_level')

# %%
# income VS family_size
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="family_size", y="income",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nincome versus family_size\n', fontsize = 12)
plt.xlabel("family_size")
plt.ylabel("income")

sns.relplot(
    data=loaned_df, x="family_size", y="income",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nincome versus family_size\n', fontsize = 12)
plt.xlabel("family_size")
plt.ylabel("income")
# Out:
# Text(3.674999999999997, 0.5, 'income')

# %%
# mortgage_amt VS family_size
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="family_size", y="mortgage_amt",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nmortgage_amt versus family_size\n', fontsize = 12)
plt.xlabel("family_size")
plt.ylabel("mortgage_amt")

sns.relplot(
    data=loaned_df, x="family_size", y="mortgage_amt",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nmortgage_amt versus family_size\n', fontsize = 12)
plt.xlabel("family_size")
plt.ylabel("mortgage_amt")
# Out:
# Text(3.674999999999997, 0.5, 'mortgage_amt')

# %%
# personal_loan VS family_size
# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="family_size", y="personal_loan",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\npersonal_loan versus family_size\n', fontsize = 12)
plt.xlabel("family_size")
plt.ylabel("personal_loan")

sns.relplot(
    data=loaned_df, x="family_size", y="personal_loan",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\npersonal_loan versus family_size\n', fontsize = 12)
plt.xlabel("family_size")
plt.ylabel("personal_loan")
# Out:
# Text(5.549999999999997, 0.5, 'personal_loan')

# %%
# income VS education_level

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="education_level", y="income",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nincome versus education_level\n', fontsize = 12)
plt.xlabel("education_level")
plt.ylabel("income")

sns.relplot(
    data=loaned_df, x="education_level", y="income",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nincome versus education_level\n', fontsize = 12)
plt.xlabel("education_level")
plt.ylabel("income")
# Out:
# Text(3.674999999999997, 0.5, 'income')

# %%
# mortgage_amt VS education_level

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="education_level", y="mortgage_amt",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nmortgage_amt versus education_level\n', fontsize = 12)
plt.xlabel("education_level")
plt.ylabel("mortgage_amt")

sns.relplot(
    data=loaned_df, x="education_level", y="mortgage_amt",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nmortgage_amt versus education_level\n', fontsize = 12)
plt.xlabel("education_level")
plt.ylabel("mortgage_amt")
# Out:
# Text(3.674999999999997, 0.5, 'mortgage_amt')

# %%
# credit_card_spend VS education_level

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="education_level", y="credit_card_spend",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\ncredit_card_spend versus education_level\n', fontsize = 12)
plt.xlabel("education_level")
plt.ylabel("credit_card_spend")

sns.relplot(
    data=loaned_df, x="education_level", y="credit_card_spend",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\ncredit_card_spend versus education_level\n', fontsize = 12)
plt.xlabel("education_level")
plt.ylabel("credit_card_spend")
# Out:
# Text(16.424999999999997, 0.5, 'credit_card_spend')

# %%
# personal_loan VS education_level

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="education_level", y="personal_loan",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\npersonal_loan versus education_level\n', fontsize = 12)
plt.xlabel("education_level")
plt.ylabel("personal_loan")

sns.relplot(
    data=loaned_df, x="education_level", y="personal_loan",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\npersonal_loan versus education_level\n', fontsize = 12)
plt.xlabel("education_level")
plt.ylabel("personal_loan")
# Out:
# Text(5.549999999999997, 0.5, 'personal_loan')

# %%
# mortgage_amt VS income

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="income", y="mortgage_amt",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nmortgage_amt versus income\n', fontsize = 12)
plt.xlabel("income")
plt.ylabel("mortgage_amt")

sns.relplot(
    data=loaned_df, x="income", y="mortgage_amt",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nmortgage_amt versus income\n', fontsize = 12)
plt.xlabel("income")
plt.ylabel("mortgage_amt")
# Out:
# Text(3.674999999999997, 0.5, 'mortgage_amt')

# %%
# credit_card_acct VS income

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="income", y="credit_card_acct",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\ncredit_card_acct versus income\n', fontsize = 12)
plt.xlabel("income")
plt.ylabel("credit_card_acct")

sns.relplot(
    data=loaned_df, x="income", y="credit_card_acct",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\ncredit_card_acct versus income\n', fontsize = 12)
plt.xlabel("income")
plt.ylabel("credit_card_acct")
# Out:
# Text(5.549999999999997, 0.5, 'credit_card_acct')

# %%
# credit_card_spend VS income

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="income", y="credit_card_spend",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\ncredit_card_spend versus income\n', fontsize = 12)
plt.xlabel("income")
plt.ylabel("credit_card_spend")

sns.relplot(
    data=loaned_df, x="income", y="credit_card_spend",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\ncredit_card_spend versus income\n', fontsize = 12)
plt.xlabel("income")
plt.ylabel("credit_card_spend")
# Out:
# Text(16.424999999999997, 0.5, 'credit_card_spend')

# %%
# personal_loan VS income

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="income", y="personal_loan",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\npersonal_loan versus income\n', fontsize = 12)
plt.xlabel("income")
plt.ylabel("personal_loan")

sns.relplot(
    data=loaned_df, x="income", y="personal_loan",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\npersonal_loand versus income\n', fontsize = 12)
plt.xlabel("income")
plt.ylabel("personal_loan")
# Out:
# Text(5.549999999999997, 0.5, 'personal_loan')

# %%
# credit_card_spend VS mortgage_amt

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="mortgage_amt", y="credit_card_spend",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\ncredit_card_spend versus mortgage_amt\n', fontsize = 12)
plt.xlabel("mortgage_amt")
plt.ylabel("credit_card_spend")

sns.relplot(
    data=loaned_df, x="mortgage_amt", y="credit_card_spend",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\ncredit_card_spend versus mortgage_amt\n', fontsize = 12)
plt.xlabel("mortgage_amt")
plt.ylabel("credit_card_spend")
# Out:
# Text(16.424999999999997, 0.5, 'credit_card_spend')

# %%
# personal_loan VS mortgage_amt

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="mortgage_amt", y="personal_loan",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\npersonal_loan versus mortgage_amt\n', fontsize = 12)
plt.xlabel("mortgage_amt")
plt.ylabel("personal_loan")

sns.relplot(
    data=loaned_df, x="mortgage_amt", y="personal_loan",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\npersonal_loan versus mortgage_amt\n', fontsize = 12)
plt.xlabel("mortgage_amt")
plt.ylabel("personal_loan")
# Out:
# Text(5.549999999999997, 0.5, 'personal_loan')

# %%
# credit_card_spend VS credit_card_acct

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="credit_card_acct", y="credit_card_spend",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\ncredit_card_spend versus credit_card_acct\n', fontsize = 12)
plt.xlabel("credit_card_acct")
plt.ylabel("credit_card_spend")

sns.relplot(
    data=loaned_df, x="credit_card_acct", y="credit_card_spend",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\ncredit_card_spend versus credit_card_acct\n', fontsize = 12)
plt.xlabel("credit_card_acct")
plt.ylabel("credit_card_spend")
# Out:
# Text(16.424999999999997, 0.5, 'credit_card_spend')

# %%
# personal_loan VS credit_card_acct

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="credit_card_acct", y="personal_loan",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\npersonal_loan versus credit_card_acct\n', fontsize = 12)
plt.xlabel("credit_card_acct")
plt.ylabel("personal_loan")

sns.relplot(
    data=loaned_df, x="credit_card_acct", y="personal_loan",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\npersonal_loan versus credit_card_acct\n', fontsize = 12)
plt.xlabel("credit_card_acct")
plt.ylabel("personal_loan")
# Out:
# Text(5.549999999999997, 0.5, 'personal_loan')

# %%
# share_trading_acct VS credit_card_spend

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="credit_card_spend", y="share_trading_acct",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nshare_trading_acct versus credit_card_spend\n', fontsize = 12)
plt.xlabel("credit_card_spend")
plt.ylabel("share_trading_acct")

sns.relplot(
    data=loaned_df, x="credit_card_spend", y="share_trading_acct",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nshare_trading_acct versus credit_card_spend\n', fontsize = 12)
plt.xlabel("credit_card_spend")
plt.ylabel("share_trading_acct")
# Out:
# Text(6.799999999999997, 0.5, 'share_trading_acct')

# %%
# fixed_deposit_acct VS credit_card_spend

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="credit_card_spend", y="fixed_deposit_acct",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nfixed_deposit_acct versus credit_card_spend\n', fontsize = 12)
plt.xlabel("credit_card_spend")
plt.ylabel("fixed_deposit_acct")

sns.relplot(
    data=loaned_df, x="credit_card_spend", y="fixed_deposit_acct",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nfixed_deposit_acct versus credit_card_spend\n', fontsize = 12)
plt.xlabel("credit_card_spend")
plt.ylabel("fixed_deposit_acct")
# Out:
# Text(6.799999999999997, 0.5, 'fixed_deposit_acct')

# %%
# online_acct VS credit_card_spend

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="credit_card_spend", y="online_acct",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nonline_acct versus credit_card_spend\n', fontsize = 12)
plt.xlabel("credit_card_spend")
plt.ylabel("online_acct")

sns.relplot(
    data=loaned_df, x="credit_card_spend", y="online_acct",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nonline_acct versus credit_card_spend\n', fontsize = 12)
plt.xlabel("credit_card_spend")
plt.ylabel("online_acct")
# Out:
# Text(5.549999999999997, 0.5, 'online_acct')

# %%
# personal_loan VS credit_card_spend

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="credit_card_spend", y="personal_loan",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\npersonal_loan versus credit_card_spend\n', fontsize = 12)
plt.xlabel("credit_card_spend")
plt.ylabel("personal_loan")

sns.relplot(
    data=loaned_df, x="credit_card_spend", y="personal_loan",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\npersonal_loan versus credit_card_spend\n', fontsize = 12)
plt.xlabel("credit_card_spend")
plt.ylabel("personal_loan")
# Out:
# Text(5.549999999999997, 0.5, 'personal_loan')

# %%
# personal_loan VS share_trading_acct

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="share_trading_acct", y="personal_loan",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\npersonal_loan versus share_trading_acct\n', fontsize = 12)
plt.xlabel("share_trading_acct")
plt.ylabel("personal_loan")

sns.relplot(
    data=loaned_df, x="share_trading_acct", y="personal_loan",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\npersonal_loan versus share_trading_acct\n', fontsize = 12)
plt.xlabel("share_trading_acct")
plt.ylabel("personal_loan")
# Out:
# Text(5.549999999999997, 0.5, 'personal_loan')

# %%
# online_acct VS fixed_deposit_acct

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="fixed_deposit_acct", y="online_acct",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\nonline_acct versus fixed_deposit_acct\n', fontsize = 12)
plt.xlabel("fixed_deposit_acct")
plt.ylabel("online_acct")

sns.relplot(
    data=loaned_df, x="fixed_deposit_acct", y="online_acct",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\nonline_acct versus fixed_deposit_acct\n', fontsize = 12)
plt.xlabel("fixed_deposit_acct")
plt.ylabel("online_acct")
# Out:
# Text(5.549999999999997, 0.5, 'online_acct')

# %%
# personal_loan VS fixed_deposit_acct

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="fixed_deposit_acct", y="personal_loan",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\npersonal_loan versus fixed_deposit_acct\n', fontsize = 12)
plt.xlabel("fixed_deposit_acct")
plt.ylabel("personal_loan")

sns.relplot(
    data=loaned_df, x="fixed_deposit_acct", y="personal_loan",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\npersonal_loan versus fixed_deposit_acct\n', fontsize = 12)
plt.xlabel("fixed_deposit_acct")
plt.ylabel("personal_loan")
# Out:
# Text(5.549999999999997, 0.5, 'personal_loan')

# %%
# personal_loan VS online_acct

# Plotting two sctter plots for loaned and not loaned based on specific attributes.
plt.figure(figsize=(12,8))

# plotting done using seaborn relplot
# https://seaborn.pydata.org/tutorial/axis_grids.html
sns.relplot(
    data=not_loaned_df, x="online_acct", y="personal_loan",
    kind="scatter", label="Not Loaned"
)
plt.title('Clients who did not loan on\npersonal_loan versus online_acct\n', fontsize = 12)
plt.xlabel("online_acct")
plt.ylabel("personal_loan")

sns.relplot(
    data=loaned_df, x="online_acct", y="personal_loan",
    kind="scatter", color='green', label="Loaned"
)
plt.title('Clients who loaned on\npersonal_loan versus online_acct\n', fontsize = 12)
plt.xlabel("online_acct")
plt.ylabel("personal_loan")
# Out:
# Text(5.549999999999997, 0.5, 'personal_loan')
